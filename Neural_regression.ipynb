# %%
import keras
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Consíderese el modelo lineal $Y=1.5X+2$ :

# %%
X=np.linspace(0,5,50) 
Y=1.5*X+2
plt.scatter(X,Y,label='y=1.5x+2',marker='.')
plt.title('Linear model')
plt.legend()
plt.show()

# %% [markdown]
# Para simular datos observacionales, le agregamos un ruido gaussiano:

# %%
noise=np.random.normal(0,1,50) 
Y=Y+noise 
plt.scatter(X,Y,label='$y=1.5x+c+N(\mu=0,\sigma=1)$') 
plt.legend() 
plt.title('Model with gaussian noise')
plt.show()

# %% [markdown]
# Ahora, queremos que una red neuronal estime los parámetros del modelo.
